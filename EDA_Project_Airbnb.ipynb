# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySharma424/Data-Science/blob/main/EDA_Project_Airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
# Air Bnb Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Dhananjay Kumar Sharma**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This capstone project aims to explore throughan Airbnb bookings dataset, the preference of customers, the behavior of hosts, pricing patterns and availability trends. As a global hospitality platform, Airbnb has petabytes of data collected from millions of listings and users. This data analysis could reveal useful insights to restore confidence-based decision making as it relates to hosts, customers and business stakeholders.
#
# The.csv file loaded has near 49,000 observations and 16 attributes, mixing both categorical and numerical variables. Listing details provided include room_type, price, neighbourhood_group, minimum_nights, number_of_reviews, reviews_per_month and availability_365. These factors give a complete depiction of the listing properties, location-centric demand and user interactions.
#
# Data understanding and cleaning: The analysis was started by understanding the data, removing values that are missing, incorrect data types, or outliers. There were missing values in columns like last_review and reviews_per_month, which were imputed properly so as not to introduce any bias into the analysis. We cleaned the price variable to avoid unrealistic outliers that might mislead our visualisation.
#
# After cleaning we perfomed Univariate and Bivariate analysis with additional inforamtion using python libraries: Pandas, NumPy, Matplotlib and Seaborn. Several plots were generated to meet the project's requirement to include at least 5 LDAs. These were bar charts, box plots, histograms, scatter plots and heatmaps.
#
# An interesting result from the study was in room type choice. Entire home/apt and private room are the most popular listings type, private rooms are lower-priced compare to entire homes/apartments but still relatively in demand for budget travelers. Whole homes—even with the higher price tag—also generate more engagement in premium markets.
#
# There was wide variability in pricing analysis between neighbourhood groups. They also share higher average prices in the central and most well-trafficked neighborhoods, suggesting strong demand. Box plots showed most of the listings are in a reasonable price range, except fine few luxury listings that drive up the maximum price.
#
# There was an inverse relationship between the price and number of reviews for a listing, meaning that cheaper listings are reviewed more - What happens next predicts this hypothesised correlation trend. Moreover, those listings which have highest availability_365 all tended to have less reviews, that is to say those high-availability-turnover apartments may be not so popular or seasonal sesame.
#
# Minimum nights is also something that came with a huge revelation for us. Properties with higher minimum night requirement receive less customer engagement suggesting that shorter stays are preferred by majority of users on this platform.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# What is the relationship between price and customer engagement (number of reviews)? and relationship between different features.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to identify key factors influencing Airbnb booking prices, demand, and listing performance to recommend competitive pricing strategies, optimize host offerings, and ultimately enhance customer satisfaction and platform revenue.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/projects/Capston Project/Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#visulating the missing values
plt.figure(figsize=(10,5))
plt.title('Missing Values count')
plt.ylabel('count')
df.isna().sum().plot(kind = 'bar', logy=True)
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
Columns = df.columns
print(Columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
Describe = df.describe()
print(Describe)
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

df.nunique()

# Unique values for categorical columns
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    print(f"\n{col}")
    print(df[col].unique())
# Out:
# name
# ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
#
# host_name
# ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
#
# neighbourhood_group
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
#
# neighbourhood
# ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
#  'East Village' 'Greenpoint' 'Bushwick' 'Flatbush' 'Lower East Side'
#  'Prospect-Lefferts Gardens' 'Long Island City' 'Kips Bay' 'SoHo'
#  'Upper East Side' 'Prospect Heights' 'Washington Heights' 'Woodside'
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
numerical_cols = df.select_dtypes(include=np.number).columns
categorical_cols = df.select_dtypes(include='object').columns

numerical_cols, categorical_cols

# Final cleaned dataset info
df.info()

# Preview cleaned data
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
#convert the last review colum to datetime object and exract the year
df['last_review'] = pd.to_datetime(df['last_review'])
df['last_review_year'] = df['last_review'].dt.year
df.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365  last_review_year
# 0                               6               365            2018.0
# 1                               2               355            2019.0

# %%
#replace null value of the last review year by medain
df['last_review_year'].fillna(df['last_review_year'].median(), inplace=True)
# Out:
# /tmp/ipykernel_1858/129243310.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['last_review_year'].fillna(df['last_review_year'].median(), inplace=True)

# %%
#replace null values of review per month by mean
df['reviews_per_month'].fillna(df['reviews_per_month'].mean(), inplace=True)
df.reviews_per_month.isna().sum()
# Out:
# /tmp/ipykernel_1858/2651961047.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reviews_per_month'].fillna(df['reviews_per_month'].mean(), inplace=True)
# np.int64(0)

# %%
df.drop(columns=['last_review'], inplace=True)
df.drop(columns=['name'], inplace=True)
df.drop(columns=['host_name'], inplace=True)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I cleaned the Airbnb dataset by handling missing values, removing invalid and extreme price values, and separating features based on data types. After manipulation, I found that pricing is strongly influenced by room type and location, lower-priced listings receive more engagement, and availability and minimum nights play a key role in demand.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure()
plt.hist(df['price'], bins=50)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Listing Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand the overall distribution and spread of prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most listings fall in the lower to mid-price range

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can create a strong positive business impact for both Airbnb and its hosts.
# By analyzing pricing patterns across room types, locations, and customer engagement levels, Airbnb can recommend competitive and data-driven pricing strategies to hosts. This helps ensure that listings are neither overpriced nor underpriced, which can lead to higher booking rates, increased customer satisfaction, and optimized revenue. Hosts who align their prices with market demand are more likely to receive frequent bookings and positive reviews, benefiting the overall platform performance.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
room_counts = df['room_type'].value_counts()

plt.figure()
plt.bar(room_counts.index, room_counts.values)
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Room Type Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare number of listings by room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Entire homes and private rooms dominate

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights will help create a positive business impact.
# By identifying popular accommodation types (such as entire homes and private rooms), Airbnb and hosts can focus on the categories that show higher customer demand and booking potential. This allows Airbnb to promote high-demand listing types, guide new hosts on what type of property to list, and help existing hosts optimize their offerings. Targeting popular accommodation types leads to higher occupancy rates, better customer satisfaction, and increased revenue for the platform.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
avg_price = df.groupby('room_type')['price'].mean()

plt.figure()
plt.bar(avg_price.index, avg_price.values)
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.title('Average Price by Room Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare pricing across room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Entire homes are most expensive and Shared rooms are cheapest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights strongly help in creating a positive business impact by guiding hosts in adopting an effective pricing strategy. The analysis shows how pricing varies across room types, locations, and customer demand levels. By understanding these patterns, hosts can price their listings competitively based on market trends, which increases the likelihood of bookings. Proper pricing leads to higher occupancy rates, improved customer satisfaction, and optimized revenue, benefiting both individual hosts and the Airbnb platform.From a business perspective, Airbnb can use these insights to provide data-driven pricing recommendations to hosts, helping prevent overpricing or underpricing. This improves overall platform performance by ensuring listings remain attractive to customers while maximizing earnings.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure()
df.boxplot(column='price', by='neighbourhood_group')
plt.xlabel('Neighbourhood Group')
plt.ylabel('Price')
plt.title('Price Distribution by Neighbourhood Group')
plt.suptitle('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze price variation across locations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Central areas have higher prices and I find the Presence of price outliers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help create a positive business impact by supporting location-based pricing decisions. The analysis shows that listing prices vary significantly across different neighbourhood groups, indicating that location plays a crucial role in determining demand and willingness to pay. Using these insights, hosts can set prices that align with local market trends, while Airbnb can recommend area-specific pricing benchmarks. This leads to higher booking conversion rates, better occupancy, and optimized revenue, benefiting both hosts and the platform.
#
# From a business standpoint, location-based pricing allows Airbnb to maximize revenue in high-demand areas while keeping listings competitive in lower-demand locations. It also improves customer experience by ensuring that prices are perceived as fair relative to the location and amenities offered.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
ng_counts = df['neighbourhood_group'].value_counts()

plt.figure()
plt.bar(ng_counts.index, ng_counts.values)
plt.xlabel('Neighbourhood Group')
plt.ylabel('Number of Listings')
plt.title('Listings by Neighbourhood Group')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand listing concentration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Manhattan and Brooklyn dominate listings

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help create a positive business impact by identifying high-demand markets. The analysis highlights neighbourhood groups with a high concentration of listings and strong customer engagement, indicating areas with consistent demand and booking potential. These insights allow Airbnb to focus marketing efforts, promotions, and host acquisition strategies in high-performing locations. Hosts can also use this information to invest in or optimize listings in demand-driven areas, resulting in higher occupancy rates and increased revenue.
#
# From a strategic perspective, identifying high-demand markets helps Airbnb improve resource allocation, prioritize customer support, and design location-specific pricing and recommendation systems. This leads to better customer satisfaction and improved platform efficiency.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure()
plt.hist(df['number_of_reviews'], bins=50)
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.title('Distribution of Reviews')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To examine customer engagement levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most listings have low review counts and Few listings are highly popular

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help create a positive business impact by highlighting top-performing listings. Through analysis of variables such as number of reviews and reviews per month, the dataset helps identify listings that receive consistently high customer engagement. These top-performing listings indicate what works well in terms of pricing, location, room type, and availability. Airbnb can use these insights to promote high-quality listings, improve recommendation systems, and share best practices with other hosts. Hosts can also benchmark their listings against top performers to improve occupancy rates and revenue.
# From a business perspective, focusing on top-performing listings improves customer satisfaction, as highly reviewed listings often deliver better experiences. It also helps Airbnb maintain platform quality and trust, which leads to higher repeat bookings and long-term growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure()
plt.scatter(df['price'], df['number_of_reviews'], alpha=0.5)
plt.xlabel('Price')
plt.ylabel('Number of Reviews')
plt.title('Price vs Number of Reviews')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To study relationship between price and demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lower-priced listings receive more reviews and also i found a negative correlation trend

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights strongly help in creating a positive business impact by supporting an optimal pricing strategy. The analysis reveals how pricing varies with factors such as room type, location, and customer engagement (number of reviews). By understanding these relationships, hosts can set prices that are competitive yet profitable, increasing the likelihood of bookings. Airbnb can further use these insights to provide data-driven pricing recommendations, which improves occupancy rates, customer satisfaction, and overall platform revenue.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure
plt.hist(df['reviews_per_month'], bins=50)
plt.xlabel('Reviews per Month')
plt.ylabel('Frequency')
plt.title('Distribution of Reviews per Month')
# Out:
# Text(0.5, 1.0, 'Distribution of Reviews per Month')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure
sns.barplot(x='last_review_year', y='number_of_reviews', data=df)
plt.xlabel('Last Review Year')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews by Last Review Year')
# Out:
# Text(0.5, 1.0, 'Number of Reviews by Last Review Year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure
sns.scatterplot(x='price', y='availability_365', data=df)
plt.xlabel('Price')
plt.ylabel('Availability_365')
plt.title('Price vs. Availability_365')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure
sns.boxplot(x='room_type', y='number_of_reviews', data=df)
plt.xlabel('Room Type')
plt.ylabel('Number of Reviews')
plt.title('Room Type vs. Number of Reviews')
# Out:
# Text(0.5, 1.0, 'Room Type vs. Number of Reviews')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Select numerical columns
num_df = df.select_dtypes(include=np.number)

# Correlation matrix
corr = num_df.corr()

plt.figure()
plt.imshow(corr)
plt.colorbar()
plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is used to understand the strength and direction of relationships between numerical variables. It helps identify which variables are positively or negatively related and whether any features are redundant.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1) number_of_reviews and reviews_per_month show a strong positive correlation, indicating that frequently booked listings receive more monthly reviews.
#
# 2) price has a weak or negative correlation with number_of_reviews, suggesting higher-priced listings tend to receive fewer bookings.
#
# 3) availability_365 shows a negative correlation with reviews, indicating popular listings are booked more often and thus less available.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns

# Pair plot for selected numerical columns
sns.pairplot(df[['price', 'number_of_reviews', 'reviews_per_month', 'availability_365']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot helps visualize pairwise relationships between multiple numerical variables simultaneously. It is useful for detecting trends, clusters, and potential linear relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Clear patterns between price and number_of_reviews confirm an inverse relationship.
#
# availability_365 and reviews_per_month show opposite trends, reinforcing demand-related insights.
#
# Diagonal plots show distribution and skewness of variables such as price.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Below is a clear, brief, and business-focused answer you can use directly in your project submission.
#
# What do you suggest the client to achieve the Business Objective?
#
# To achieve the business objective, I would suggest the client (Airbnb) to adopt a data-driven decision-making approach based on insights obtained from the analysis.
#
# First, Airbnb should implement dynamic and location-based pricing strategies. Since price and demand vary significantly across neighbourhoods and room types, recommending competitive prices to hosts based on market trends can help increase bookings and optimize revenue.
#
# Second, the client should focus on promoting high-demand room types and locations. Entire homes and private rooms in popular neighbourhoods show higher engagement. Targeted marketing and personalized recommendations in these segments can improve customer satisfaction and conversion rates.
#
# Third, Airbnb should encourage hosts to maintain flexible booking policies, such as lower minimum night requirements and optimized availability. Listings with shorter minimum stays and balanced availability tend to receive more reviews, indicating higher demand.
#
# Additionally, the client can use insights from reviews and engagement metrics to improve listing quality. Highlighting best practices from top-performing listings and providing feedback to underperforming hosts can enhance overall platform quality.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project successfully performed an Exploratory Data Analysis (EDA) on the Airbnb NYC 2019 dataset to understand key factors influencing pricing, demand, and listing performance. Through systematic data cleaning, handling of missing values, and visualization-driven analysis, meaningful insights were derived from a large and diverse real-world dataset.
#
# The analysis revealed that location and room type are the most influential factors in determining listing prices. Entire homes and private rooms dominate the market, while shared rooms show comparatively lower demand. Pricing trends indicate that lower-priced listings generally receive higher customer engagement, as reflected by the number of reviews, whereas higher-priced listings tend to experience reduced demand. This highlights the importance of competitive and data-driven pricing strategies.
#
# Customer engagement analysis showed that listings with shorter minimum night requirements and balanced availability tend to perform better. Highly available listings often receive fewer reviews, suggesting lower demand, while popular listings remain booked for most of the year. Review-based metrics further helped identify top-performing listings and patterns that contribute to customer satisfaction.
#
# Correlation and pairwise analysis confirmed relationships among numerical variables, strengthening confidence in the insights obtained from individual visualizations. These findings not only support business decision-making but also provide a strong foundation for future predictive modeling, such as price prediction or demand forecasting.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
